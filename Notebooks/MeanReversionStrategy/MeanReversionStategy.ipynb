# %%
import yfinance as yf
import numpy as np
import pandas as pd
import tensorflow as tf
import csv
import matplotlib.pyplot as plt
plt.style.use("seaborn")
pd.options.mode.chained_assignment = None
# Out:
# 2023-09-28 16:15:03.595434: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import backtesting_system_MeanReversionStrategy as bt

# %%
tester = bt.Backtest("EURUSD=x")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.df
# Out:
#                Close       SMA  Lower_bb  Upper_bb  distance  position  \
# Date
# 2006-02-10  1.190703  1.208687  1.188281  1.229092 -0.017984       0.0
# 2006-02-13  1.191199  1.209004  1.190091  1.227916 -0.017804       0.0
# 2006-02-14  1.191597  1.208613  1.188755  1.228472 -0.017017       0.0
# 2006-02-15  1.188594  1.207860  1.186733  1.228987 -0.019266       0.0
# 2006-02-16  1.190703  1.207194  1.185193  1.229194 -0.016491       0.0
# ...              ...       ...       ...       ...       ...       ...
# 2022-08-30  1.001402  1.015034  0.993254  1.036814 -0.013632       1.0
# 2022-08-31  1.002506  1.014347  0.992324  1.036370 -0.011840       1.0
# 2022-09-01  1.003905  1.013868  0.991575  1.036160 -0.009962       1.0
# 2022-09-02  0.995233  1.012972  0.989903  1.036041 -0.017739       1.0
# 2022-09-05  0.990943  1.012002  0.987746  1.036259 -0.021060       0.0
#
#             Trade_Signal       PnL    cumPnL
# Date
# 2006-02-10           NaN       NaN       NaN
# ...

# %%
tester.profit
# Out:
# 0.1680639386177063

# %% [markdown]
# which is correct

# %% [markdown]
# check if the plot module works

# %%
tester.plot(start="2019-01-01", end="2019-12-31")

# %%
tester.plot(start="2019-01-01", end="2019-12-31", cols=["Close", "SMA", "Lower_bb", "Upper_bb"])

# %%
tester.plot(start="2019-01-01", end="2019-12-31", cols=["Close", "SMA", "Lower_bb", "Upper_bb"], with_signal=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# The above exception was the direct cause of the following exception:
#
# ...
