# %%
import yfinance as yf
import numpy as np
import pandas as pd
import tensorflow as tf
import csv
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# 2023-09-28 15:57:37.691366: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import backtesting_system_MeanReversionStrategy as bt

# %%
tester = bt.Backtest("EURUSD=x")
# Out:
# [*********************100%***********************]  1 of 1 completed
# /Users/akiraalexanderwan/Documents/GitHub/Algorithmic_Trading/Notebooks/MeanReversionStrategy/backtesting_system_MeanReversionStrategy.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df["SMA"] = self.df.Close.rolling(SMA).mean()
# /Users/akiraalexanderwan/Documents/GitHub/Algorithmic_Trading/Notebooks/MeanReversionStrategy/backtesting_system_MeanReversionStrategy.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df["Lower_bb"] = self.df.SMA - self.df.Close.rolling(SMA).std() * devs[0]
# /Users/akiraalexanderwan/Documents/GitHub/Algorithmic_Trading/Notebooks/MeanReversionStrategy/backtesting_system_MeanReversionStrategy.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df["Upper_bb"] = self.df.SMA + self.df.Close.rolling(SMA).std() * devs[1]
# /Users/akiraalexanderwan/Documents/GitHub/Algorithmic_Trading/Notebooks/MeanReversionStrategy/backtesting_system_MeanReversionStrategy.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df["distance"] = self.df.Close - self.df.SMA
# /Users/akiraalexanderwan/Documents/GitHub/Algorithmic_Trading/Notebooks/MeanReversionStrategy/backtesting_system_MeanReversionStrategy.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df.dropna(inplace = True)
# /Users/akiraalexanderwan/Documents/GitHub/Algorithmic_Trading/Notebooks/MeanReversionStrategy/backtesting_system_MeanReversionStrategy.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df["position"] = np.where(self.df.Close < self.df.Lower_bb, 1, np.nan)
# /Users/akiraalexanderwan/Documents/GitHub/Algorithmic_Trading/Notebooks/MeanReversionStrategy/backtesting_system_MeanReversionStrategy.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df["position"] = np.where(self.df.Close > self.df.Upper_bb, -1, self.df["position"])
# /Users/akiraalexanderwan/Documents/GitHub/Algorithmic_Trading/Notebooks/MeanReversionStrategy/backtesting_system_MeanReversionStrategy.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df["position"] = np.where(self.df.distance * self.df.distance.shift(1) < 0, 0, self.df.position)
# /Users/akiraalexanderwan/Documents/GitHub/Algorithmic_Trading/Notebooks/MeanReversionStrategy/backtesting_system_MeanReversionStrategy.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df["position"] = self.df.position.ffill().fillna(0)
# /Users/akiraalexanderwan/Documents/GitHub/Algorithmic_Trading/Notebooks/MeanReversionStrategy/backtesting_system_MeanReversionStrategy.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df["Trade_Signal"] = self.df.position- self.df.position.shift(1)
# /Users/akiraalexanderwan/Documents/GitHub/Algorithmic_Trading/Notebooks/MeanReversionStrategy/backtesting_system_MeanReversionStrategy.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df["PnL"] = np.nan
# /Users/akiraalexanderwan/Documents/GitHub/Algorithmic_Trading/Notebooks/MeanReversionStrategy/backtesting_system_MeanReversionStrategy.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df["cumPnL"] = self.df["PnL"].cumsum()

# %%
#tester.show_df()

# %%
tester.df
# Out:
#                Close       SMA  Lower_bb  Upper_bb  distance  position  \
# Date
# 2006-02-10  1.190703  1.208687  1.188281  1.229092 -0.017984       0.0
# 2006-02-13  1.191199  1.209004  1.190091  1.227916 -0.017804       0.0
# 2006-02-14  1.191597  1.208613  1.188755  1.228472 -0.017017       0.0
# 2006-02-15  1.188594  1.207860  1.186733  1.228987 -0.019266       0.0
# 2006-02-16  1.190703  1.207194  1.185193  1.229194 -0.016491       0.0
# ...              ...       ...       ...       ...       ...       ...
# 2022-08-30  1.001402  1.015034  0.993254  1.036814 -0.013632       1.0
# 2022-08-31  1.002506  1.014347  0.992324  1.036370 -0.011840       1.0
# 2022-09-01  1.003905  1.013868  0.991575  1.036160 -0.009962       1.0
# 2022-09-02  0.995233  1.012972  0.989903  1.036041 -0.017739       1.0
# 2022-09-05  0.990943  1.012002  0.987746  1.036259 -0.021060       0.0
#
#             Trade_Signal       PnL    cumPnL
# Date
# 2006-02-10           NaN       NaN       NaN
# 2006-02-13           0.0       NaN       NaN
# 2006-02-14           0.0       NaN       NaN
# 2006-02-15           0.0       NaN       NaN
# 2006-02-16           0.0       NaN       NaN
# ...                  ...       ...       ...
# 2022-08-30           0.0       NaN       NaN
# 2022-08-31           0.0       NaN       NaN
# 2022-09-01           0.0       NaN       NaN
# 2022-09-02           0.0       NaN       NaN
# 2022-09-05          -1.0 -0.003004  0.168064
#
# [4295 rows x 9 columns]
