# %%
import yfinance as yf
import numpy as np
import pandas as pd
import tensorflow as tf
import csv
import matplotlib.pyplot as plt
plt.style.use("seaborn")
pd.options.mode.chained_assignment = None
# Out:
# 2023-09-29 19:09:59.158641: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import backtesting_system_MeanReversionStrategy as bt

# %%
tester = bt.Backtest("EURUSD=x")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.df
# Out:
#                Price       SMA  Lower_bb  Upper_bb  distance  position  \
# Date
# 2006-02-10  1.190703  1.208687  1.188281  1.229092 -0.017984       0.0
# 2006-02-13  1.191199  1.209004  1.190091  1.227916 -0.017804       0.0
# 2006-02-14  1.191597  1.208613  1.188755  1.228472 -0.017017       0.0
# 2006-02-15  1.188594  1.207860  1.186733  1.228987 -0.019266       0.0
# 2006-02-16  1.190703  1.207194  1.185193  1.229194 -0.016491       0.0
# ...              ...       ...       ...       ...       ...       ...
# 2022-08-30  1.001402  1.015034  0.993254  1.036814 -0.013632       1.0
# 2022-08-31  1.002506  1.014347  0.992324  1.036370 -0.011840       1.0
# 2022-09-01  1.003905  1.013868  0.991575  1.036160 -0.009962       1.0
# 2022-09-02  0.995233  1.012972  0.989903  1.036041 -0.017739       1.0
# 2022-09-05  0.990943  1.012002  0.987746  1.036259 -0.021060       0.0
#
#             Trade_Signal       PnL    cumPnL
# Date
# 2006-02-10           NaN       NaN       NaN
# 2006-02-13           0.0       NaN       NaN
# 2006-02-14           0.0       NaN       NaN
# 2006-02-15           0.0       NaN       NaN
# 2006-02-16           0.0       NaN       NaN
# ...                  ...       ...       ...
# 2022-08-30           0.0       NaN       NaN
# 2022-08-31           0.0       NaN       NaN
# 2022-09-01           0.0       NaN       NaN
# 2022-09-02           0.0       NaN       NaN
# 2022-09-05          -1.0 -0.003004  0.168064
#
# [4295 rows x 9 columns]

# %%
tester.profit
# Out:
# 0.1680639386177063

# %% [markdown]
# which is correct

# %% [markdown]
# check if the plot module works

# %%
tester.plot(start="2019-01-01", end="2019-12-31")

# %%
tester.plot(start="2019-01-01", end="2019-12-31", cols=["Price", "SMA", "Lower_bb", "Upper_bb"])

# %%
tester.plot(start="2019-01-01", end="2020-12-31", cols=["Price", "SMA", "Lower_bb", "Upper_bb"], with_signal=True)

# %%
tester.plot_PnL(start="2019-01-01", end="2022-12-31", cumulative=True)

# %%
tester2 = bt.Backtest("GBPUSD_1_15.csv", yahoo=False)

# %%
tester2.df
# Out:
#                       Price       SMA  Lower_bb  Upper_bb  distance  position  \
# Date
# 2023-02-12 22:29:00  1.2060  1.206330  1.205538  1.207122 -0.000330       0.0
# 2023-02-12 22:30:00  1.2059  1.206297  1.205520  1.207073 -0.000397       0.0
# 2023-02-12 22:31:00  1.2060  1.206270  1.205510  1.207030 -0.000270       0.0
# 2023-02-12 22:32:00  1.2059  1.206240  1.205496  1.206984 -0.000340       0.0
# 2023-02-12 22:33:00  1.2059  1.206207  1.205496  1.206917 -0.000307       0.0
# ...                     ...       ...       ...       ...       ...       ...
# 2023-06-15 15:55:00  1.2743  1.274570  1.274106  1.275034 -0.000270       0.0
# 2023-06-15 15:56:00  1.2742  1.274570  1.274106  1.275034 -0.000370       0.0
# 2023-06-15 15:57:00  1.2743  1.274567  1.274096  1.275037 -0.000267       0.0
# 2023-06-15 15:58:00  1.2741  1.274567  1.274096  1.275037 -0.000467       0.0
# 2023-06-15 15:59:00  1.2743  1.274563  1.274086  1.275040 -0.000263       0.0
#
#                      Trade_Signal  PnL  cumPnL
# Date
# 2023-02-12 22:29:00           NaN  NaN     NaN
# 2023-02-12 22:30:00           0.0  NaN     NaN
# 2023-02-12 22:31:00           0.0  NaN     NaN
# 2023-02-12 22:32:00           0.0  NaN     NaN
# 2023-02-12 22:33:00           0.0  NaN     NaN
# ...                           ...  ...     ...
# 2023-06-15 15:55:00           0.0  NaN     NaN
# 2023-06-15 15:56:00           0.0  NaN     NaN
# 2023-06-15 15:57:00           0.0  NaN     NaN
# 2023-06-15 15:58:00           0.0  NaN     NaN
# 2023-06-15 15:59:00           0.0  NaN     NaN
#
# [129871 rows x 9 columns]

# %%
tester2.profit
# Out:
# 0.28079999999999994

# %%
tester2.plot("2023-04-09", "2023-04-10", cols=["Price", "SMA", "Lower_bb", "Upper_bb"])

# %%
tester2.plot("2023-04-09", "2023-04-10", cols=["Price", "SMA", "Lower_bb", "Upper_bb"], with_signal=True)

# %%
tester2.plot_PnL(start="2023-06-13")

# %%
tester2.plot_PnL(start="2023-06-13", cumulative=True)
