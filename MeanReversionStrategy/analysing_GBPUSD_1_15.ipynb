# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import csv
plt.style.use("seaborn")

# %%
data = yf.download('GBPUSD=x','2023-08-25','2023-09-01',interval='1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data["Close"]
# Out:
# Datetime
# 2023-08-25 00:00:00    1.259858
# 2023-08-25 00:01:00    1.259700
# 2023-08-25 00:02:00    1.259573
# 2023-08-25 00:03:00    1.259589
# 2023-08-25 00:04:00    1.259509
#                          ...
# 2023-08-31 23:54:00    1.267154
# 2023-08-31 23:55:00    1.267106
# 2023-08-31 23:56:00    1.267090
# 2023-08-31 23:57:00    1.267058
# 2023-08-31 23:58:00    1.267042
# Name: Close, Length: 6961, dtype: float64

# %%
df = pd.read_csv("GBPUSD_1_15.csv", names=["Date", "Price"], header=None, index_col=0, dayfirst=True)

# %% [markdown]
# you can also make the index into the date by doing this below:

# %%
df.set_index(["Date"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/ym/zxt7rwrx44s222zyh_0_7d6w0000gn/T/ipykernel_4148/4095656200.py in <module>
# ----> 1 df.set_index(["Date"], inplace=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5501
#    5502         if missing:
# -> 5503             raise KeyError(f"None of {missing} are in the columns")
#    5504
#    5505         if inplace:
#
# KeyError: "None of ['Date'] are in the columns"

# %%
df
# Out:
#                    Price
# Date
# 12/02/2023 22:00  1.2069
# 12/02/2023 22:01  1.2068
# 12/02/2023 22:02  1.2068
# 12/02/2023 22:03  1.2069
# 12/02/2023 22:04  1.2069
# ...                  ...
# 15/06/2023 15:55  1.2743
# 15/06/2023 15:56  1.2742
# 15/06/2023 15:57  1.2743
# 15/06/2023 15:58  1.2741
# 15/06/2023 15:59  1.2743
#
# [129900 rows x 1 columns]

# %%
df.index = pd.to_datetime(df.index, dayfirst=True)
df.index
# Out:
# DatetimeIndex(['2023-02-12 22:00:00', '2023-02-12 22:01:00',
#                '2023-02-12 22:02:00', '2023-02-12 22:03:00',
#                '2023-02-12 22:04:00', '2023-02-12 22:05:00',
#                '2023-02-12 22:06:00', '2023-02-12 22:07:00',
#                '2023-02-12 22:08:00', '2023-02-12 22:09:00',
#                ...
#                '2023-06-15 15:50:00', '2023-06-15 15:51:00',
#                '2023-06-15 15:52:00', '2023-06-15 15:53:00',
#                '2023-06-15 15:54:00', '2023-06-15 15:55:00',
#                '2023-06-15 15:56:00', '2023-06-15 15:57:00',
#                '2023-06-15 15:58:00', '2023-06-15 15:59:00'],
#               dtype='datetime64[ns]', name='Date', length=129900, freq=None)

# %%
df
# Out:
#                       Price
# Date
# 2023-02-12 22:00:00  1.2069
# 2023-02-12 22:01:00  1.2068
# 2023-02-12 22:02:00  1.2068
# 2023-02-12 22:03:00  1.2069
# 2023-02-12 22:04:00  1.2069
# ...                     ...
# 2023-06-15 15:55:00  1.2743
# 2023-06-15 15:56:00  1.2742
# 2023-06-15 15:57:00  1.2743
# 2023-06-15 15:58:00  1.2741
# 2023-06-15 15:59:00  1.2743
#
# [129900 rows x 1 columns]

# %%
df.plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.describe()
# Out:
#                Price
# count  129900.000000
# mean        1.232965
# std         0.020883
# min         1.180800
# 25%         1.215000
# 50%         1.240700
# 75%         1.247800
# max         1.274900

# %%
df.info
# Out:
# <bound method DataFrame.info of                       Price
# Date
# 2023-02-12 22:00:00  1.2069
# 2023-02-12 22:01:00  1.2068
# 2023-02-12 22:02:00  1.2068
# 2023-02-12 22:03:00  1.2069
# 2023-02-12 22:04:00  1.2069
# ...                     ...
# 2023-06-15 15:55:00  1.2743
# 2023-06-15 15:56:00  1.2742
# 2023-06-15 15:57:00  1.2743
# 2023-06-15 15:58:00  1.2741
# 2023-06-15 15:59:00  1.2743
#
# [129900 rows x 1 columns]>

# %%
df.loc["2023-03-12"]
# Out:
#                       Price
# Date
# 2023-03-12 18:02:00  1.2034
# 2023-03-12 18:06:00  1.2034
# 2023-03-12 18:07:00  1.2032
# 2023-03-12 18:16:00  1.2030
# 2023-03-12 18:21:00  1.2030
# ...                     ...
# 2023-03-12 23:55:00  1.2082
# 2023-03-12 23:56:00  1.2080
# 2023-03-12 23:57:00  1.2078
# 2023-03-12 23:58:00  1.2074
# 2023-03-12 23:59:00  1.2077
#
# [318 rows x 1 columns]

# %%
df.loc["2023-03-12"].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Date'>
